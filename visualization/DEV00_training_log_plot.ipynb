# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
log_path = '/glade/work/ksha/CREDIT_runs/wxformer_6h/backup_multi_stage1/training_log.csv'
log_path2 = '/glade/work/ksha/CREDIT_runs/wxformer_6h/training_log.csv'

logs = pd.read_csv(log_path)
logs2 = pd.read_csv(log_path2)

train_mae = np.array(logs['train_mae'])
valid_mae = np.array(logs['valid_mae'])

train_mae2 = np.array(logs2['train_mae'])
valid_mae2 = np.array(logs2['valid_mae'])


train_mae_full = np.concatenate((train_mae, train_mae2), axis=0)
valid_mae_full = np.concatenate((valid_mae, valid_mae2), axis=0)

plt.plot()
L = np.arange(len(train_mae_full))
plt.plot(L, train_mae_full, label='Training MAE (lr=1E-4, cosine annealing)')
plt.plot(L, valid_mae_full, label='Validation MAE')

plt.axvline(x=15, color='r', linestyle='--', label='Epoch 15 (re-start with lr=1E-5 and cosine)')

plt.legend()
plt.xlabel('Epoch')
plt.ylabel('MAE')
plt.title('Wxformer 6 hourly multi-step training from 06-48 hr\nTraining and Validation MAE')
# Out:
# Text(0.5, 1.0, 'Wxformer 6 hourly multi-step training from 06-48 hr\nTraining and Validation MAE')

# %%
train_mae
# Out:
# array([0.13700937, 0.13180105, 0.13006593, 0.12819034, 0.12664892,
#        0.12596634, 0.12532914, 0.12510899, 0.12441706, 0.12348833,
#        0.12310048, 0.12225349, 0.12161493, 0.12108609, 0.12037368])

# %%
log_path1 = '/glade/work/ksha/CREDIT_runs/fuxi_6h/backup_multi_stage1/training_log.csv'
log_path2 = '/glade/work/ksha/CREDIT_runs/fuxi_6h/backup_multi_stage2/training_log.csv'
log_path3 = '/glade/work/ksha/CREDIT_runs/fuxi_6h/training_log.csv'

logs1 = pd.read_csv(log_path1)
logs2 = pd.read_csv(log_path2)
logs3 = pd.read_csv(log_path3)

train_mae1 = np.array(logs1['train_mae'])
valid_mae1 = np.array(logs1['valid_mae'])

train_mae2 = np.array(logs2['train_mae'])
valid_mae2 = np.array(logs2['valid_mae'])

train_mae3 = np.array(logs3['train_mae'])
valid_mae3 = np.array(logs3['valid_mae'])

train_mae_full = np.concatenate((train_mae1, train_mae2, train_mae3), axis=0)
valid_mae_full = np.concatenate((valid_mae1, valid_mae2, valid_mae3), axis=0)

plt.plot()
L = np.arange(len(train_mae_full))
plt.plot(L, train_mae_full, label='Training MAE (lr=1E-4, cosine annealing)')
plt.plot(L, valid_mae_full, label='Validation MAE')

plt.axvline(x=11, color='r', linestyle='--', label='Epoch 11 (re-start with lr=1E-5 and cosine)')

plt.legend()
plt.xlabel('Epoch')
plt.ylabel('MAE')
plt.title('FuXi 6 hourly multi-step training from 06-48 hr\nTraining and Validation MAE')
# Out:
# Text(0.5, 1.0, 'FuXi 6 hourly multi-step training from 06-48 hr\nTraining and Validation MAE')

# %%
train_mae3
# Out:
# array([0.10990354])

# %%
train_mae2
# Out:
# array([0.11165322, 0.11077864, 0.11081667, 0.11065073, 0.11052574,
#        0.11040263])

# %%
log_path = '/glade/work/ksha/CREDIT_runs/fuxi_1h/backup_single_stage1/training_log.csv'
log_path2 = '/glade/work/ksha/CREDIT_runs/fuxi_1h/training_log.csv'

logs = pd.read_csv(log_path)
logs2 = pd.read_csv(log_path2)

train_mae = np.array(logs['train_mae'])
valid_mae = np.array(logs['valid_mae'])

train_mae2 = np.array(logs2['train_mae'])
valid_mae2 = np.array(logs2['valid_mae'])


train_mae_full = np.concatenate((train_mae, train_mae2), axis=0)[2:]
valid_mae_full = np.concatenate((valid_mae, valid_mae2), axis=0)[2:]

plt.plot()
L = np.arange(len(train_mae_full))
plt.plot(L, train_mae_full, label='Training MAE (lr=1E-3, cosine annealing)')
plt.plot(L, valid_mae_full, label='Validation MAE')

plt.axvline(x=22, color='r', linestyle='--', label='Epoch 22 (re-start with lr=1E-4 and cosine)')

plt.legend()
plt.xlabel('Epoch')
plt.ylabel('MAE')
plt.title('FuXi 1 hourly single-step training (train_mae)\nTraining and Validation MAE')
# Out:
# Text(0.5, 1.0, 'FuXi 1 hourly single-step training (train_mae)\nTraining and Validation MAE')

# %%
log_path = '/glade/work/ksha/CREDIT_runs/wxformer_1h/backup_single_stage1/training_log.csv'
log_path2 = '/glade/work/ksha/CREDIT_runs/wxformer_1h/training_log.csv'

logs = pd.read_csv(log_path)
logs2 = pd.read_csv(log_path2)

train_mae = np.array(logs['train_mae'])
valid_mae = np.array(logs['valid_mae'])

train_mae2 = np.array(logs2['train_mae'])
valid_mae2 = np.array(logs2['valid_mae'])


train_mae_full = np.concatenate((train_mae, train_mae2), axis=0)[2:]
valid_mae_full = np.concatenate((valid_mae, valid_mae2), axis=0)[2:]

plt.plot()
L = np.arange(len(train_mae_full))
plt.plot(L, train_mae_full, label='Training MAE (lr=1E-3, cosine annealing)')
plt.plot(L, valid_mae_full, label='Validation MAE')

plt.axvline(x=22, color='r', linestyle='--', label='Epoch 22 (re-start with lr=1E-4 and cosine)')

plt.legend()
plt.xlabel('Epoch')
plt.ylabel('MAE')
plt.title('FuXi 1 hourly single-step training (train_mae)\nTraining and Validation MAE')
# Out:
# Text(0.5, 1.0, 'FuXi 1 hourly single-step training (train_mae)\nTraining and Validation MAE')

# %%
4000*52 / 10681
# Out:
# 19.47383203819867

# %%
10681
